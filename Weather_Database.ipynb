# %%
# Import the dependencies
import pandas as pd
import requests
import numpy as np
from citipy import citipy


# Import the API keys
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high= 90.000, size=1500)
lngs = np.random.uniform(low = -180.000, high= 180.000, size=1500)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each lat and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is uniqe, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# # Psuedocode
# 1. Create 1st retrieval -> capture latitude and longitude, maximum temperature, percent humidity, percent cloudiness, wind speed, weather description
#     -create DataFrame1 with new list, ensuring city
# 2. Create 2nd retrieval -> if same coordinates has rain, fetch rain, else add zer0
#     -create DataFrame2 with new list, ensuring city
# 3. Create 3rd retrieval -> if same coordinates has snow, fetch snow, else add zer0
#     -create DataFrame3 with new list, ensuring city
# 4. Join all three DataFrames on city
#     a. Join DataFrame1 and DataFrame2 as DataFrameX
#     b. Join DataFrameX and DataFrame3 as DataFrame
# 5. Write file as CSV(WeatherPy_challenge), answer the question using Pandas methods: How many cities have recorded rainfall or snow?

# %%
# Create an empty list to hold the weather data
city_data1 = []

# Print the beginning of the logging
print(" .xX-> RETRIEVAL OF DATA1 HAS COMMENCED <-Xx. ")
print("---------------------------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
#  .xX-> RETRIEVAL OF DATA1 HAS COMMENCED <-Xx.
# ---------------------------------------------

# %%
# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
           
        # Append the city information into city_data list
        city_data1.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

# if an error is experienced, skip the city
    except:
        print("No city we found, move on we must...")
        pass
    
# Indicate that Data Loading is complete
print("---------------------------------------------")
print(" .xX-> RETRIEVAL OF DATA1 HAS COMPLETED <-Xx. ")
print("---------------------------------------------")
# Out:
# Processing Record 1 of Set 1 | praia
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | buariki
# No city we found, move on we must...
# Processing Record 9 of Set 1 | geraldton
# Processing Record 10 of Set 1 | kamphaeng phet
# Processing Record 11 of Set 1 | severnyy-kospashskiy
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | gilgil
# No city we found, move on we must...
# Processing Record 14 of Set 1 | sivaki
# Processing Record 15 of Set 1 | dalinghe
# No city we found, move on we must...
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | mahina
# Processing Record 18 of Set 1 | marsh harbour
# Processing Record 19 of Set 1 | meulaboh
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | puerto escondido
# Processing Record 22 of Set 1 | sobolevo
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | tres passos
# Processing Record 27 of Set 1 | tezu
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | peniche
# Processing Record 32 of Set 1 | kurchum
# Processing Record 33 of Set 1 | potiskum
# Processing Record 34 of Set 1 | bellmead
# Processing Record 35 of Set 1 | bam
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | suntar
# Processing Record 38 of Set 1 | cururupu
# Processing Record 39 of Set 1 | kaseda
# Processing Record 40 of Set 1 | sfantu gheorghe
# Processing Record 41 of Set 1 | deputatskiy
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | muli
# Processing Record 46 of Set 1 | grimshaw
# Processing Record 47 of Set 1 | nioro
# Processing Record 48 of Set 1 | hualmay
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | mandan
# Processing Record 1 of Set 2 | simao
# Processing Record 2 of Set 2 | barentsburg
# No city we found, move on we must...
# Processing Record 3 of Set 2 | sovetskiy
# Processing Record 4 of Set 2 | toropets
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | woerden
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | dunedin
# Processing Record 9 of Set 2 | vao
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | vila franca do campo
# Processing Record 13 of Set 2 | simbahan
# Processing Record 14 of Set 2 | banjar
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | huarmey
# Processing Record 18 of Set 2 | taolanaro
# No city we found, move on we must...
# Processing Record 19 of Set 2 | moctezuma
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | umm lajj
# Processing Record 22 of Set 2 | port-gentil
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | ugoofaaru
# Processing Record 25 of Set 2 | kuytun
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | prince rupert
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | celestun
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | grindavik
# Processing Record 32 of Set 2 | maine-soroa
# Processing Record 33 of Set 2 | pakokku
# Processing Record 34 of Set 2 | sao miguel do araguaia
# Processing Record 35 of Set 2 | odessa
# Processing Record 36 of Set 2 | cayenne
# Processing Record 37 of Set 2 | katsuura
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | hami
# Processing Record 40 of Set 2 | tidore
# No city we found, move on we must...
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | starkville
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | herat
# Processing Record 48 of Set 2 | kalabo
# Processing Record 49 of Set 2 | luganville
# Processing Record 50 of Set 2 | nantucket
# Processing Record 1 of Set 3 | santa cruz
# Processing Record 2 of Set 3 | sambava
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | tawkar
# No city we found, move on we must...
# Processing Record 5 of Set 3 | ketchikan
# Processing Record 6 of Set 3 | oranjemund
# Processing Record 7 of Set 3 | sorong
# Processing Record 8 of Set 3 | kandila
# Processing Record 9 of Set 3 | ashtian
# Processing Record 10 of Set 3 | beringovskiy
# Processing Record 11 of Set 3 | puerto narino
# Processing Record 12 of Set 3 | wenling
# Processing Record 13 of Set 3 | moron
# Processing Record 14 of Set 3 | bontang
# Processing Record 15 of Set 3 | te anau
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | castro
# Processing Record 19 of Set 3 | daryapur
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | tabou
# Processing Record 22 of Set 3 | alice springs
# Processing Record 23 of Set 3 | sabha
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | alto araguaia
# Processing Record 26 of Set 3 | buy
# Processing Record 27 of Set 3 | mackay
# Processing Record 28 of Set 3 | grand gaube
# Processing Record 29 of Set 3 | palabuhanratu
# No city we found, move on we must...
# Processing Record 30 of Set 3 | sanmenxia
# Processing Record 31 of Set 3 | kiruna
# Processing Record 32 of Set 3 | half moon bay
# Processing Record 33 of Set 3 | san pedro
# Processing Record 34 of Set 3 | harper
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | wheeling
# Processing Record 37 of Set 3 | bara
# Processing Record 38 of Set 3 | grand river south east
# No city we found, move on we must...
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | vilyuysk
# Processing Record 42 of Set 3 | sankt valentin
# Processing Record 43 of Set 3 | galgani
# No city we found, move on we must...
# Processing Record 44 of Set 3 | north platte
# Processing Record 45 of Set 3 | bedele
# Processing Record 46 of Set 3 | port alfred
# Processing Record 47 of Set 3 | pedro ii
# Processing Record 48 of Set 3 | sao joao da barra
# Processing Record 49 of Set 3 | san cristobal
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | elat
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | amberley
# Processing Record 4 of Set 4 | axim
# Processing Record 5 of Set 4 | kiama
# Processing Record 6 of Set 4 | nanortalik
# Processing Record 7 of Set 4 | tuatapere
# Processing Record 8 of Set 4 | lincoln
# Processing Record 9 of Set 4 | ixtapa
# Processing Record 10 of Set 4 | champerico
# Processing Record 11 of Set 4 | bandrele
# Processing Record 12 of Set 4 | vestmannaeyjar
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | rutland
# Processing Record 15 of Set 4 | lavras
# Processing Record 16 of Set 4 | kupang
# Processing Record 17 of Set 4 | tasiilaq
# Processing Record 18 of Set 4 | shache
# Processing Record 19 of Set 4 | namie
# Processing Record 20 of Set 4 | harbour breton
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | porto santo
# Processing Record 23 of Set 4 | beniganj
# Processing Record 24 of Set 4 | samusu
# No city we found, move on we must...
# Processing Record 25 of Set 4 | sol-iletsk
# Processing Record 26 of Set 4 | dharchula
# Processing Record 27 of Set 4 | trinidad
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | mys shmidta
# No city we found, move on we must...
# Processing Record 30 of Set 4 | sabang
# Processing Record 31 of Set 4 | nawada
# Processing Record 32 of Set 4 | lompoc
# Processing Record 33 of Set 4 | buraydah
# Processing Record 34 of Set 4 | bargal
# No city we found, move on we must...
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | walvis bay
# Processing Record 37 of Set 4 | gazanjyk
# Processing Record 38 of Set 4 | sapernoye
# Processing Record 39 of Set 4 | nyurba
# Processing Record 40 of Set 4 | chitral
# Processing Record 41 of Set 4 | taltal
# Processing Record 42 of Set 4 | rungata
# No city we found, move on we must...
# Processing Record 43 of Set 4 | mar del plata
# Processing Record 44 of Set 4 | attawapiskat
# No city we found, move on we must...
# Processing Record 45 of Set 4 | japura
# Processing Record 46 of Set 4 | atasu
# Processing Record 47 of Set 4 | batsfjord
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | norman wells
# Processing Record 50 of Set 4 | dafeng
# Processing Record 1 of Set 5 | caravelas
# Processing Record 2 of Set 5 | avarua
# Processing Record 3 of Set 5 | santiago del estero
# Processing Record 4 of Set 5 | bathsheba
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | beloha
# Processing Record 7 of Set 5 | koumac
# Processing Record 8 of Set 5 | bacolod
# Processing Record 9 of Set 5 | lucapa
# Processing Record 10 of Set 5 | kathmandu
# Processing Record 11 of Set 5 | kirensk
# Processing Record 12 of Set 5 | namtsy
# Processing Record 13 of Set 5 | balezino
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | roma
# Processing Record 16 of Set 5 | sijunjung
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | charters towers
# Processing Record 19 of Set 5 | puerto ayacucho
# Processing Record 20 of Set 5 | ilulissat
# Processing Record 21 of Set 5 | isangel
# Processing Record 22 of Set 5 | yuzhno-yeniseyskiy
# No city we found, move on we must...
# Processing Record 23 of Set 5 | necochea
# Processing Record 24 of Set 5 | belushya guba
# No city we found, move on we must...
# Processing Record 25 of Set 5 | sinnamary
# Processing Record 26 of Set 5 | kota kinabalu
# Processing Record 27 of Set 5 | lagoa
# Processing Record 28 of Set 5 | bambous virieux
# Processing Record 29 of Set 5 | kisanga
# Processing Record 30 of Set 5 | ilo
# Processing Record 31 of Set 5 | labuhan
# Processing Record 32 of Set 5 | parrita
# Processing Record 33 of Set 5 | kismayo
# Processing Record 34 of Set 5 | mayumba
# Processing Record 35 of Set 5 | amahai
# Processing Record 36 of Set 5 | henties bay
# Processing Record 37 of Set 5 | matara
# Processing Record 38 of Set 5 | brae
# Processing Record 39 of Set 5 | laguna
# Processing Record 40 of Set 5 | nhulunbuy
# Processing Record 41 of Set 5 | pacific grove
# Processing Record 42 of Set 5 | pastavy
# Processing Record 43 of Set 5 | pandavapura
# Processing Record 44 of Set 5 | klaksvik
# Processing Record 45 of Set 5 | clyde river
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | ormara
# Processing Record 48 of Set 5 | kargasok
# Processing Record 49 of Set 5 | lebu
# Processing Record 50 of Set 5 | toftir
# No city we found, move on we must...
# Processing Record 1 of Set 6 | hunza
# No city we found, move on we must...
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | cap malheureux
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | khorramshahr
# Processing Record 6 of Set 6 | poum
# Processing Record 7 of Set 6 | georgetown
# Processing Record 8 of Set 6 | verkhovazhye
# Processing Record 9 of Set 6 | hihifo
# No city we found, move on we must...
# Processing Record 10 of Set 6 | comodoro rivadavia
# Processing Record 11 of Set 6 | college
# Processing Record 12 of Set 6 | rocha
# Processing Record 13 of Set 6 | almeirim
# Processing Record 14 of Set 6 | bolungarvik
# No city we found, move on we must...
# Processing Record 15 of Set 6 | constitucion
# Processing Record 16 of Set 6 | east london
# Processing Record 17 of Set 6 | warqla
# No city we found, move on we must...
# Processing Record 18 of Set 6 | chiang klang
# Processing Record 19 of Set 6 | genoa
# Processing Record 20 of Set 6 | rovaniemi
# Processing Record 21 of Set 6 | bengkulu
# Processing Record 22 of Set 6 | san policarpo
# Processing Record 23 of Set 6 | camalu
# Processing Record 24 of Set 6 | cabedelo
# Processing Record 25 of Set 6 | kavieng
# Processing Record 26 of Set 6 | vila do maio
# Processing Record 27 of Set 6 | cumaribo
# No city we found, move on we must...
# Processing Record 28 of Set 6 | mozarlandia
# Processing Record 29 of Set 6 | aquiraz
# Processing Record 30 of Set 6 | ilhabela
# Processing Record 31 of Set 6 | hambantota
# Processing Record 32 of Set 6 | dingle
# Processing Record 33 of Set 6 | chicama
# Processing Record 34 of Set 6 | taywarah
# Processing Record 35 of Set 6 | nikolskoye
# Processing Record 36 of Set 6 | nefteyugansk
# Processing Record 37 of Set 6 | demirci
# Processing Record 38 of Set 6 | dombarovskiy
# Processing Record 39 of Set 6 | snezhnogorsk
# Processing Record 40 of Set 6 | ust-nera
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | trunovskoye
# Processing Record 43 of Set 6 | takoradi
# Processing Record 44 of Set 6 | miri
# Processing Record 45 of Set 6 | bay roberts
# Processing Record 46 of Set 6 | launceston
# Processing Record 47 of Set 6 | naftah
# No city we found, move on we must...
# Processing Record 48 of Set 6 | gavle
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | vaitupu
# No city we found, move on we must...
# Processing Record 1 of Set 7 | guiyang
# Processing Record 2 of Set 7 | amderma
# No city we found, move on we must...
# Processing Record 3 of Set 7 | muros
# Processing Record 4 of Set 7 | aykhal
# Processing Record 5 of Set 7 | itarema
# Processing Record 6 of Set 7 | batemans bay
# Processing Record 7 of Set 7 | zhanatas
# No city we found, move on we must...
# Processing Record 8 of Set 7 | tumannyy
# No city we found, move on we must...
# Processing Record 9 of Set 7 | kangaatsiaq
# Processing Record 10 of Set 7 | north bend
# Processing Record 11 of Set 7 | arlit
# Processing Record 12 of Set 7 | raymond
# Processing Record 13 of Set 7 | sisimiut
# Processing Record 14 of Set 7 | nemuro
# Processing Record 15 of Set 7 | madison
# Processing Record 16 of Set 7 | krasnyy chikoy
# Processing Record 17 of Set 7 | oriximina
# Processing Record 18 of Set 7 | teacapan
# Processing Record 19 of Set 7 | camargo
# Processing Record 20 of Set 7 | linshu
# No city we found, move on we must...
# Processing Record 21 of Set 7 | atar
# Processing Record 22 of Set 7 | sentyabrskiy
# No city we found, move on we must...
# Processing Record 23 of Set 7 | seoul
# Processing Record 24 of Set 7 | doha
# Processing Record 25 of Set 7 | muborak
# Processing Record 26 of Set 7 | progreso
# Processing Record 27 of Set 7 | lasa
# Processing Record 28 of Set 7 | codrington
# Processing Record 29 of Set 7 | margate
# Processing Record 30 of Set 7 | plouzane
# Processing Record 31 of Set 7 | la palma
# Processing Record 32 of Set 7 | coahuayana
# Processing Record 33 of Set 7 | san juan
# Processing Record 34 of Set 7 | shelburne
# Processing Record 35 of Set 7 | kenai
# Processing Record 36 of Set 7 | varca
# Processing Record 37 of Set 7 | tessalit
# Processing Record 38 of Set 7 | nizhneyansk
# No city we found, move on we must...
# Processing Record 39 of Set 7 | yumen
# Processing Record 40 of Set 7 | lazaro cardenas
# Processing Record 41 of Set 7 | krasnoarmeysk
# Processing Record 42 of Set 7 | ararat
# Processing Record 43 of Set 7 | noshiro
# Processing Record 44 of Set 7 | nampa
# Processing Record 45 of Set 7 | utiroa
# No city we found, move on we must...
# Processing Record 46 of Set 7 | gursarai
# Processing Record 47 of Set 7 | volsk
# Processing Record 48 of Set 7 | veraval
# Processing Record 49 of Set 7 | coquimbo
# Processing Record 50 of Set 7 | mareeba
# Processing Record 1 of Set 8 | narsaq
# Processing Record 2 of Set 8 | berlevag
# Processing Record 3 of Set 8 | ahipara
# Processing Record 4 of Set 8 | nicoya
# Processing Record 5 of Set 8 | abong mbang
# Processing Record 6 of Set 8 | olden
# Processing Record 7 of Set 8 | illoqqortoormiut
# No city we found, move on we must...
# Processing Record 8 of Set 8 | padre paraiso
# Processing Record 9 of Set 8 | marawi
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | qaqortoq
# Processing Record 12 of Set 8 | tomatlan
# Processing Record 13 of Set 8 | kinkala
# Processing Record 14 of Set 8 | nouakchott
# Processing Record 15 of Set 8 | zhuhai
# Processing Record 16 of Set 8 | kattivakkam
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | gamboula
# Processing Record 19 of Set 8 | umm jarr
# No city we found, move on we must...
# Processing Record 20 of Set 8 | matagami
# Processing Record 21 of Set 8 | guerrero negro
# Processing Record 22 of Set 8 | pineville
# Processing Record 23 of Set 8 | verkhnevilyuysk
# Processing Record 24 of Set 8 | ilesha
# Processing Record 25 of Set 8 | balkhash
# Processing Record 26 of Set 8 | sandpoint
# Processing Record 27 of Set 8 | huambo
# Processing Record 28 of Set 8 | tsihombe
# No city we found, move on we must...
# Processing Record 29 of Set 8 | mehamn
# Processing Record 30 of Set 8 | hofn
# Processing Record 31 of Set 8 | palmer
# Processing Record 32 of Set 8 | cartagena
# Processing Record 33 of Set 8 | balvanesti
# Processing Record 34 of Set 8 | korla
# Processing Record 35 of Set 8 | panguipulli
# Processing Record 36 of Set 8 | lieksa
# Processing Record 37 of Set 8 | solnechnyy
# Processing Record 38 of Set 8 | bandar
# Processing Record 39 of Set 8 | montgomery
# Processing Record 40 of Set 8 | kauhajoki
# Processing Record 41 of Set 8 | port-cartier
# Processing Record 42 of Set 8 | srednekolymsk
# Processing Record 43 of Set 8 | stornoway
# Processing Record 44 of Set 8 | vanimo
# Processing Record 45 of Set 8 | chokurdakh
# Processing Record 46 of Set 8 | epe
# Processing Record 47 of Set 8 | benjamin constant
# Processing Record 48 of Set 8 | eenhana
# Processing Record 49 of Set 8 | koutselion
# Processing Record 50 of Set 8 | mindelo
# Processing Record 1 of Set 9 | hurricane
# Processing Record 2 of Set 9 | smithers
# Processing Record 3 of Set 9 | severo-kurilsk
# Processing Record 4 of Set 9 | martinsville
# Processing Record 5 of Set 9 | aldan
# Processing Record 6 of Set 9 | mocuba
# Processing Record 7 of Set 9 | san rafael
# Processing Record 8 of Set 9 | bukama
# Processing Record 9 of Set 9 | souillac
# Processing Record 10 of Set 9 | morros
# Processing Record 11 of Set 9 | asfi
# Processing Record 12 of Set 9 | kungur
# Processing Record 13 of Set 9 | kyabe
# Processing Record 14 of Set 9 | mrirt
# No city we found, move on we must...
# Processing Record 15 of Set 9 | rawson
# Processing Record 16 of Set 9 | tulu bolo
# Processing Record 17 of Set 9 | castano primo
# Processing Record 18 of Set 9 | beni
# Processing Record 19 of Set 9 | lorengau
# Processing Record 20 of Set 9 | atambua
# Processing Record 21 of Set 9 | port hardy
# Processing Record 22 of Set 9 | hasaki
# Processing Record 23 of Set 9 | bajil
# Processing Record 24 of Set 9 | maceio
# Processing Record 25 of Set 9 | ribeira grande
# Processing Record 26 of Set 9 | kudahuvadhoo
# Processing Record 27 of Set 9 | tsementnyy
# Processing Record 28 of Set 9 | tilichiki
# Processing Record 29 of Set 9 | zhigansk
# Processing Record 30 of Set 9 | kruisfontein
# Processing Record 31 of Set 9 | talaya
# Processing Record 32 of Set 9 | mount isa
# Processing Record 33 of Set 9 | egvekinot
# Processing Record 34 of Set 9 | zaysan
# Processing Record 35 of Set 9 | piet retief
# Processing Record 36 of Set 9 | colotlan
# Processing Record 37 of Set 9 | enshi
# Processing Record 38 of Set 9 | barstow
# Processing Record 39 of Set 9 | mount gambier
# Processing Record 40 of Set 9 | ceska skalice
# Processing Record 41 of Set 9 | tazovskiy
# Processing Record 42 of Set 9 | saint-pierre
# Processing Record 43 of Set 9 | luderitz
# Processing Record 44 of Set 9 | batangafo
# Processing Record 45 of Set 9 | igarka
# Processing Record 46 of Set 9 | sinjai
# Processing Record 47 of Set 9 | umba
# Processing Record 48 of Set 9 | zemio
# Processing Record 49 of Set 9 | fergus falls
# Processing Record 50 of Set 9 | rayachoti
# Processing Record 1 of Set 10 | goderich
# Processing Record 2 of Set 10 | ilabaya
# Processing Record 3 of Set 10 | troitskoye
# Processing Record 4 of Set 10 | nome
# Processing Record 5 of Set 10 | cockburn town
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | manggar
# Processing Record 8 of Set 10 | micheweni
# Processing Record 9 of Set 10 | port moresby
# Processing Record 10 of Set 10 | amazar
# Processing Record 11 of Set 10 | oga
# Processing Record 12 of Set 10 | alyangula
# Processing Record 13 of Set 10 | kamaishi
# Processing Record 14 of Set 10 | kangavar
# Processing Record 15 of Set 10 | beyneu
# Processing Record 16 of Set 10 | tamandare
# Processing Record 17 of Set 10 | saint-augustin
# Processing Record 18 of Set 10 | vanavara
# Processing Record 19 of Set 10 | asind
# Processing Record 20 of Set 10 | klyuchi
# Processing Record 21 of Set 10 | santiago
# Processing Record 22 of Set 10 | lashio
# Processing Record 23 of Set 10 | karratha
# Processing Record 24 of Set 10 | saleaula
# No city we found, move on we must...
# Processing Record 25 of Set 10 | port hedland
# Processing Record 26 of Set 10 | okha
# Processing Record 27 of Set 10 | mayo
# Processing Record 28 of Set 10 | kachikau
# No city we found, move on we must...
# Processing Record 29 of Set 10 | mezen
# Processing Record 30 of Set 10 | portland
# Processing Record 31 of Set 10 | malanje
# Processing Record 32 of Set 10 | guanica
# Processing Record 33 of Set 10 | haibowan
# No city we found, move on we must...
# Processing Record 34 of Set 10 | teya
# Processing Record 35 of Set 10 | sorvag
# No city we found, move on we must...
# Processing Record 36 of Set 10 | harwich
# Processing Record 37 of Set 10 | juneau
# Processing Record 38 of Set 10 | urusha
# Processing Record 39 of Set 10 | doctor pedro p. pena
# No city we found, move on we must...
# Processing Record 40 of Set 10 | mwaya
# Processing Record 41 of Set 10 | naberera
# Processing Record 42 of Set 10 | mishan
# Processing Record 43 of Set 10 | paracuru
# Processing Record 44 of Set 10 | nong khai
# Processing Record 45 of Set 10 | cabo san lucas
# Processing Record 46 of Set 10 | yucca valley
# Processing Record 47 of Set 10 | karaul
# No city we found, move on we must...
# Processing Record 48 of Set 10 | ratne
# Processing Record 49 of Set 10 | hay river
# Processing Record 50 of Set 10 | buribay
# Processing Record 1 of Set 11 | fukue
# Processing Record 2 of Set 11 | ambon
# Processing Record 3 of Set 11 | diffa
# Processing Record 4 of Set 11 | asau
# Processing Record 5 of Set 11 | santa eulalia del rio
# No city we found, move on we must...
# Processing Record 6 of Set 11 | iracoubo
# Processing Record 7 of Set 11 | santa marta
# Processing Record 8 of Set 11 | ukiah
# Processing Record 9 of Set 11 | quatre cocos
# Processing Record 10 of Set 11 | longyearbyen
# Processing Record 11 of Set 11 | kilindoni
# Processing Record 12 of Set 11 | chiali
# No city we found, move on we must...
# Processing Record 13 of Set 11 | inderborskiy
# No city we found, move on we must...
# Processing Record 14 of Set 11 | mapastepec
# Processing Record 15 of Set 11 | esil
# Processing Record 16 of Set 11 | zalantun
# Processing Record 17 of Set 11 | tiarei
# Processing Record 18 of Set 11 | camasca
# Processing Record 19 of Set 11 | koksovyy
# Processing Record 20 of Set 11 | nagato
# Processing Record 21 of Set 11 | plettenberg bay
# Processing Record 22 of Set 11 | sretensk
# Processing Record 23 of Set 11 | acarau
# Processing Record 24 of Set 11 | ayan
# Processing Record 25 of Set 11 | kissidougou
# Processing Record 26 of Set 11 | pokhara
# Processing Record 27 of Set 11 | chagda
# No city we found, move on we must...
# Processing Record 28 of Set 11 | gao
# Processing Record 29 of Set 11 | puerto carreno
# Processing Record 30 of Set 11 | impfondo
# Processing Record 31 of Set 11 | dali
# Processing Record 32 of Set 11 | jiayuguan
# Processing Record 33 of Set 11 | morondava
# Processing Record 34 of Set 11 | kerteh
# No city we found, move on we must...
# Processing Record 35 of Set 11 | loanda
# Processing Record 36 of Set 11 | port lincoln
# Processing Record 37 of Set 11 | kamenskoye
# No city we found, move on we must...
# Processing Record 38 of Set 11 | adrar
# Processing Record 39 of Set 11 | bogotol
# Processing Record 40 of Set 11 | bojnurd
# Processing Record 41 of Set 11 | doba
# Processing Record 42 of Set 11 | la paz
# Processing Record 43 of Set 11 | moussoro
# Processing Record 44 of Set 11 | manbij
# Processing Record 45 of Set 11 | sayat
# Processing Record 46 of Set 11 | knysna
# Processing Record 47 of Set 11 | yulara
# Processing Record 48 of Set 11 | omagari
# Processing Record 49 of Set 11 | burnie
# Processing Record 50 of Set 11 | dalianwan
# Processing Record 1 of Set 12 | boende
# Processing Record 2 of Set 12 | jubayl
# No city we found, move on we must...
# Processing Record 3 of Set 12 | havre-saint-pierre
# Processing Record 4 of Set 12 | sinnar
# Processing Record 5 of Set 12 | ciudad real
# Processing Record 6 of Set 12 | hashtrud
# Processing Record 7 of Set 12 | tommot
# Processing Record 8 of Set 12 | aybak
# No city we found, move on we must...
# Processing Record 9 of Set 12 | malwan
# No city we found, move on we must...
# Processing Record 10 of Set 12 | mwinilunga
# Processing Record 11 of Set 12 | taburi
# No city we found, move on we must...
# Processing Record 12 of Set 12 | itoman
# Processing Record 13 of Set 12 | hobyo
# Processing Record 14 of Set 12 | balad
# Processing Record 15 of Set 12 | kolokani
# Processing Record 16 of Set 12 | port hueneme
# Processing Record 17 of Set 12 | kalevala
# Processing Record 18 of Set 12 | mandalgovi
# Processing Record 19 of Set 12 | mamallapuram
# Processing Record 20 of Set 12 | khammam
# Processing Record 21 of Set 12 | litovko
# Processing Record 22 of Set 12 | morro bay
# Processing Record 23 of Set 12 | dzhebariki-khaya
# Processing Record 24 of Set 12 | swellendam
# Processing Record 25 of Set 12 | luau
# Processing Record 26 of Set 12 | dalby
# Processing Record 27 of Set 12 | pala
# Processing Record 28 of Set 12 | muroto
# Processing Record 29 of Set 12 | moranbah
# Processing Record 30 of Set 12 | barranca
# Processing Record 31 of Set 12 | shimoda
# Processing Record 32 of Set 12 | vrangel
# Processing Record 33 of Set 12 | skibbereen
# Processing Record 34 of Set 12 | camana
# Processing Record 35 of Set 12 | dong xoai
# Processing Record 36 of Set 12 | springbok
# Processing Record 37 of Set 12 | ekibastuz
# Processing Record 38 of Set 12 | flekkefjord
# Processing Record 39 of Set 12 | port hawkesbury
# Processing Record 40 of Set 12 | palmerston
# Processing Record 41 of Set 12 | ossora
# Processing Record 42 of Set 12 | camocim
# Processing Record 43 of Set 12 | san antonio
# Processing Record 44 of Set 12 | nishihara
# Processing Record 45 of Set 12 | halalo
# No city we found, move on we must...
# Processing Record 46 of Set 12 | storsteinnes
# Processing Record 47 of Set 12 | port blair
# Processing Record 48 of Set 12 | edgewater
# Processing Record 49 of Set 12 | bonthe
# Processing Record 50 of Set 12 | revelstoke
# Processing Record 1 of Set 13 | wattegama
# Processing Record 2 of Set 13 | gat
# Processing Record 3 of Set 13 | bako
# Processing Record 4 of Set 13 | kindu
# Processing Record 5 of Set 13 | bourail
# Processing Record 6 of Set 13 | kamenka
# Processing Record 7 of Set 13 | flin flon
# Processing Record 8 of Set 13 | laje
# Processing Record 9 of Set 13 | zhangjiakou
# Processing Record 10 of Set 13 | boysun
# Processing Record 11 of Set 13 | linchuan
# No city we found, move on we must...
# Processing Record 12 of Set 13 | bikin
# Processing Record 13 of Set 13 | rapid valley
# Processing Record 14 of Set 13 | kaputa
# Processing Record 15 of Set 13 | westport
# Processing Record 16 of Set 13 | gimbi
# Processing Record 17 of Set 13 | sao jose da coroa grande
# Processing Record 18 of Set 13 | hovd
# Processing Record 19 of Set 13 | lavrentiya
# Processing Record 20 of Set 13 | namatanai
# ---------------------------------------------
#  .xX-> RETRIEVAL OF DATA1 HAS COMPLETED <-Xx.
# ---------------------------------------------

# %%
# Print city_data to confirm sufficient count
len(city_data1)
# Out:
# 566

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data1_df = pd.DataFrame(city_data1)

# %%
# Create an empty list to hold the weather data
city_data2 = []

# Print the beginning of the logging
print(" .xX-> RETRIEVAL OF DATA2 HAS COMMENCED <-Xx. ")
print("---------------------------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
#  .xX-> RETRIEVAL OF DATA2 HAS COMMENCED <-Xx.
# ---------------------------------------------

# %%
# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
       
        # Parse out the needed data - 3h.
        city_rain = city_weather["rain"]["3h"]
    
        # Append the rain information into city_data2 list
        city_data2.append({"City": city.title(),
                           "Rain (Inches)": city_rain
                           })
    except:    
        try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
       
            # Parse out the needed data - 1h.
            city_rain = city_weather["rain"]["1h"]
            
             # Append the rain information into city_data2 list
            city_data2.append({"City": city.title(),
                               "Rain (Inches)": city_rain
                               })
    
        except:
             # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
       
            # Append the rain information into city_data2 list
            city_data2.append({"City": city.title(),
                              "Rain (Inches)": 0
                              })
    
    pass
    
# Indicate that Data Loading is complete
print("---------------------------------------------")
print(" .xX-> RETRIEVAL OF DATA2 HAS COMPLETED <-Xx. ")
print("---------------------------------------------")
# Out:
# Processing Record 1 of Set 1 | praia
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | buariki
# Processing Record 9 of Set 1 | geraldton
# Processing Record 10 of Set 1 | kamphaeng phet
# Processing Record 11 of Set 1 | severnyy-kospashskiy
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | gilgil
# Processing Record 14 of Set 1 | sivaki
# Processing Record 15 of Set 1 | dalinghe
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | mahina
# Processing Record 18 of Set 1 | marsh harbour
# Processing Record 19 of Set 1 | meulaboh
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | puerto escondido
# Processing Record 22 of Set 1 | sobolevo
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | tres passos
# Processing Record 27 of Set 1 | tezu
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | peniche
# Processing Record 32 of Set 1 | kurchum
# Processing Record 33 of Set 1 | potiskum
# Processing Record 34 of Set 1 | bellmead
# Processing Record 35 of Set 1 | bam
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | suntar
# Processing Record 38 of Set 1 | cururupu
# Processing Record 39 of Set 1 | kaseda
# Processing Record 40 of Set 1 | sfantu gheorghe
# Processing Record 41 of Set 1 | deputatskiy
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | muli
# Processing Record 46 of Set 1 | grimshaw
# Processing Record 47 of Set 1 | nioro
# Processing Record 48 of Set 1 | hualmay
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | mandan
# Processing Record 1 of Set 2 | simao
# Processing Record 2 of Set 2 | barentsburg
# Processing Record 3 of Set 2 | sovetskiy
# Processing Record 4 of Set 2 | toropets
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | woerden
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | dunedin
# Processing Record 9 of Set 2 | vao
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | vila franca do campo
# Processing Record 13 of Set 2 | simbahan
# Processing Record 14 of Set 2 | banjar
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | huarmey
# Processing Record 18 of Set 2 | taolanaro
# Processing Record 19 of Set 2 | moctezuma
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | umm lajj
# Processing Record 22 of Set 2 | port-gentil
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | ugoofaaru
# Processing Record 25 of Set 2 | kuytun
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | prince rupert
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | celestun
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | grindavik
# Processing Record 32 of Set 2 | maine-soroa
# Processing Record 33 of Set 2 | pakokku
# Processing Record 34 of Set 2 | sao miguel do araguaia
# Processing Record 35 of Set 2 | odessa
# Processing Record 36 of Set 2 | cayenne
# Processing Record 37 of Set 2 | katsuura
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | hami
# Processing Record 40 of Set 2 | tidore
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | starkville
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | herat
# Processing Record 48 of Set 2 | kalabo
# Processing Record 49 of Set 2 | luganville
# Processing Record 50 of Set 2 | nantucket
# Processing Record 1 of Set 3 | santa cruz
# Processing Record 2 of Set 3 | sambava
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | tawkar
# Processing Record 5 of Set 3 | ketchikan
# Processing Record 6 of Set 3 | oranjemund
# Processing Record 7 of Set 3 | sorong
# Processing Record 8 of Set 3 | kandila
# Processing Record 9 of Set 3 | ashtian
# Processing Record 10 of Set 3 | beringovskiy
# Processing Record 11 of Set 3 | puerto narino
# Processing Record 12 of Set 3 | wenling
# Processing Record 13 of Set 3 | moron
# Processing Record 14 of Set 3 | bontang
# Processing Record 15 of Set 3 | te anau
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | castro
# Processing Record 19 of Set 3 | daryapur
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | tabou
# Processing Record 22 of Set 3 | alice springs
# Processing Record 23 of Set 3 | sabha
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | alto araguaia
# Processing Record 26 of Set 3 | buy
# Processing Record 27 of Set 3 | mackay
# Processing Record 28 of Set 3 | grand gaube
# Processing Record 29 of Set 3 | palabuhanratu
# Processing Record 30 of Set 3 | sanmenxia
# Processing Record 31 of Set 3 | kiruna
# Processing Record 32 of Set 3 | half moon bay
# Processing Record 33 of Set 3 | san pedro
# Processing Record 34 of Set 3 | harper
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | wheeling
# Processing Record 37 of Set 3 | bara
# Processing Record 38 of Set 3 | grand river south east
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | vilyuysk
# Processing Record 42 of Set 3 | sankt valentin
# Processing Record 43 of Set 3 | galgani
# Processing Record 44 of Set 3 | north platte
# Processing Record 45 of Set 3 | bedele
# Processing Record 46 of Set 3 | port alfred
# Processing Record 47 of Set 3 | pedro ii
# Processing Record 48 of Set 3 | sao joao da barra
# Processing Record 49 of Set 3 | san cristobal
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | elat
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | amberley
# Processing Record 4 of Set 4 | axim
# Processing Record 5 of Set 4 | kiama
# Processing Record 6 of Set 4 | nanortalik
# Processing Record 7 of Set 4 | tuatapere
# Processing Record 8 of Set 4 | lincoln
# Processing Record 9 of Set 4 | ixtapa
# Processing Record 10 of Set 4 | champerico
# Processing Record 11 of Set 4 | bandrele
# Processing Record 12 of Set 4 | vestmannaeyjar
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | rutland
# Processing Record 15 of Set 4 | lavras
# Processing Record 16 of Set 4 | kupang
# Processing Record 17 of Set 4 | tasiilaq
# Processing Record 18 of Set 4 | shache
# Processing Record 19 of Set 4 | namie
# Processing Record 20 of Set 4 | harbour breton
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | porto santo
# Processing Record 23 of Set 4 | beniganj
# Processing Record 24 of Set 4 | samusu
# Processing Record 25 of Set 4 | sol-iletsk
# Processing Record 26 of Set 4 | dharchula
# Processing Record 27 of Set 4 | trinidad
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | mys shmidta
# Processing Record 30 of Set 4 | sabang
# Processing Record 31 of Set 4 | nawada
# Processing Record 32 of Set 4 | lompoc
# Processing Record 33 of Set 4 | buraydah
# Processing Record 34 of Set 4 | bargal
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | walvis bay
# Processing Record 37 of Set 4 | gazanjyk
# Processing Record 38 of Set 4 | sapernoye
# Processing Record 39 of Set 4 | nyurba
# Processing Record 40 of Set 4 | chitral
# Processing Record 41 of Set 4 | taltal
# Processing Record 42 of Set 4 | rungata
# Processing Record 43 of Set 4 | mar del plata
# Processing Record 44 of Set 4 | attawapiskat
# Processing Record 45 of Set 4 | japura
# Processing Record 46 of Set 4 | atasu
# Processing Record 47 of Set 4 | batsfjord
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | norman wells
# Processing Record 50 of Set 4 | dafeng
# Processing Record 1 of Set 5 | caravelas
# Processing Record 2 of Set 5 | avarua
# Processing Record 3 of Set 5 | santiago del estero
# Processing Record 4 of Set 5 | bathsheba
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | beloha
# Processing Record 7 of Set 5 | koumac
# Processing Record 8 of Set 5 | bacolod
# Processing Record 9 of Set 5 | lucapa
# Processing Record 10 of Set 5 | kathmandu
# Processing Record 11 of Set 5 | kirensk
# Processing Record 12 of Set 5 | namtsy
# Processing Record 13 of Set 5 | balezino
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | roma
# Processing Record 16 of Set 5 | sijunjung
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | charters towers
# Processing Record 19 of Set 5 | puerto ayacucho
# Processing Record 20 of Set 5 | ilulissat
# Processing Record 21 of Set 5 | isangel
# Processing Record 22 of Set 5 | yuzhno-yeniseyskiy
# Processing Record 23 of Set 5 | necochea
# Processing Record 24 of Set 5 | belushya guba
# Processing Record 25 of Set 5 | sinnamary
# Processing Record 26 of Set 5 | kota kinabalu
# Processing Record 27 of Set 5 | lagoa
# Processing Record 28 of Set 5 | bambous virieux
# Processing Record 29 of Set 5 | kisanga
# Processing Record 30 of Set 5 | ilo
# Processing Record 31 of Set 5 | labuhan
# Processing Record 32 of Set 5 | parrita
# Processing Record 33 of Set 5 | kismayo
# Processing Record 34 of Set 5 | mayumba
# Processing Record 35 of Set 5 | amahai
# Processing Record 36 of Set 5 | henties bay
# Processing Record 37 of Set 5 | matara
# Processing Record 38 of Set 5 | brae
# Processing Record 39 of Set 5 | laguna
# Processing Record 40 of Set 5 | nhulunbuy
# Processing Record 41 of Set 5 | pacific grove
# Processing Record 42 of Set 5 | pastavy
# Processing Record 43 of Set 5 | pandavapura
# Processing Record 44 of Set 5 | klaksvik
# Processing Record 45 of Set 5 | clyde river
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | ormara
# Processing Record 48 of Set 5 | kargasok
# Processing Record 49 of Set 5 | lebu
# Processing Record 50 of Set 5 | toftir
# Processing Record 1 of Set 6 | hunza
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | cap malheureux
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | khorramshahr
# Processing Record 6 of Set 6 | poum
# Processing Record 7 of Set 6 | georgetown
# Processing Record 8 of Set 6 | verkhovazhye
# Processing Record 9 of Set 6 | hihifo
# Processing Record 10 of Set 6 | comodoro rivadavia
# Processing Record 11 of Set 6 | college
# Processing Record 12 of Set 6 | rocha
# Processing Record 13 of Set 6 | almeirim
# Processing Record 14 of Set 6 | bolungarvik
# Processing Record 15 of Set 6 | constitucion
# Processing Record 16 of Set 6 | east london
# Processing Record 17 of Set 6 | warqla
# Processing Record 18 of Set 6 | chiang klang
# Processing Record 19 of Set 6 | genoa
# Processing Record 20 of Set 6 | rovaniemi
# Processing Record 21 of Set 6 | bengkulu
# Processing Record 22 of Set 6 | san policarpo
# Processing Record 23 of Set 6 | camalu
# Processing Record 24 of Set 6 | cabedelo
# Processing Record 25 of Set 6 | kavieng
# Processing Record 26 of Set 6 | vila do maio
# Processing Record 27 of Set 6 | cumaribo
# Processing Record 28 of Set 6 | mozarlandia
# Processing Record 29 of Set 6 | aquiraz
# Processing Record 30 of Set 6 | ilhabela
# Processing Record 31 of Set 6 | hambantota
# Processing Record 32 of Set 6 | dingle
# Processing Record 33 of Set 6 | chicama
# Processing Record 34 of Set 6 | taywarah
# Processing Record 35 of Set 6 | nikolskoye
# Processing Record 36 of Set 6 | nefteyugansk
# Processing Record 37 of Set 6 | demirci
# Processing Record 38 of Set 6 | dombarovskiy
# Processing Record 39 of Set 6 | snezhnogorsk
# Processing Record 40 of Set 6 | ust-nera
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | trunovskoye
# Processing Record 43 of Set 6 | takoradi
# Processing Record 44 of Set 6 | miri
# Processing Record 45 of Set 6 | bay roberts
# Processing Record 46 of Set 6 | launceston
# Processing Record 47 of Set 6 | naftah
# Processing Record 48 of Set 6 | gavle
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | vaitupu
# Processing Record 1 of Set 7 | guiyang
# Processing Record 2 of Set 7 | amderma
# Processing Record 3 of Set 7 | muros
# Processing Record 4 of Set 7 | aykhal
# Processing Record 5 of Set 7 | itarema
# Processing Record 6 of Set 7 | batemans bay
# Processing Record 7 of Set 7 | zhanatas
# Processing Record 8 of Set 7 | tumannyy
# Processing Record 9 of Set 7 | kangaatsiaq
# Processing Record 10 of Set 7 | north bend
# Processing Record 11 of Set 7 | arlit
# Processing Record 12 of Set 7 | raymond
# Processing Record 13 of Set 7 | sisimiut
# Processing Record 14 of Set 7 | nemuro
# Processing Record 15 of Set 7 | madison
# Processing Record 16 of Set 7 | krasnyy chikoy
# Processing Record 17 of Set 7 | oriximina
# Processing Record 18 of Set 7 | teacapan
# Processing Record 19 of Set 7 | camargo
# Processing Record 20 of Set 7 | linshu
# Processing Record 21 of Set 7 | atar
# Processing Record 22 of Set 7 | sentyabrskiy
# Processing Record 23 of Set 7 | seoul
# Processing Record 24 of Set 7 | doha
# Processing Record 25 of Set 7 | muborak
# Processing Record 26 of Set 7 | progreso
# Processing Record 27 of Set 7 | lasa
# Processing Record 28 of Set 7 | codrington
# Processing Record 29 of Set 7 | margate
# Processing Record 30 of Set 7 | plouzane
# Processing Record 31 of Set 7 | la palma
# Processing Record 32 of Set 7 | coahuayana
# Processing Record 33 of Set 7 | san juan
# Processing Record 34 of Set 7 | shelburne
# Processing Record 35 of Set 7 | kenai
# Processing Record 36 of Set 7 | varca
# Processing Record 37 of Set 7 | tessalit
# Processing Record 38 of Set 7 | nizhneyansk
# Processing Record 39 of Set 7 | yumen
# Processing Record 40 of Set 7 | lazaro cardenas
# Processing Record 41 of Set 7 | krasnoarmeysk
# Processing Record 42 of Set 7 | ararat
# Processing Record 43 of Set 7 | noshiro
# Processing Record 44 of Set 7 | nampa
# Processing Record 45 of Set 7 | utiroa
# Processing Record 46 of Set 7 | gursarai
# Processing Record 47 of Set 7 | volsk
# Processing Record 48 of Set 7 | veraval
# Processing Record 49 of Set 7 | coquimbo
# Processing Record 50 of Set 7 | mareeba
# Processing Record 1 of Set 8 | narsaq
# Processing Record 2 of Set 8 | berlevag
# Processing Record 3 of Set 8 | ahipara
# Processing Record 4 of Set 8 | nicoya
# Processing Record 5 of Set 8 | abong mbang
# Processing Record 6 of Set 8 | olden
# Processing Record 7 of Set 8 | illoqqortoormiut
# Processing Record 8 of Set 8 | padre paraiso
# Processing Record 9 of Set 8 | marawi
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | qaqortoq
# Processing Record 12 of Set 8 | tomatlan
# Processing Record 13 of Set 8 | kinkala
# Processing Record 14 of Set 8 | nouakchott
# Processing Record 15 of Set 8 | zhuhai
# Processing Record 16 of Set 8 | kattivakkam
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | gamboula
# Processing Record 19 of Set 8 | umm jarr
# Processing Record 20 of Set 8 | matagami
# Processing Record 21 of Set 8 | guerrero negro
# Processing Record 22 of Set 8 | pineville
# Processing Record 23 of Set 8 | verkhnevilyuysk
# Processing Record 24 of Set 8 | ilesha
# Processing Record 25 of Set 8 | balkhash
# Processing Record 26 of Set 8 | sandpoint
# Processing Record 27 of Set 8 | huambo
# Processing Record 28 of Set 8 | tsihombe
# Processing Record 29 of Set 8 | mehamn
# Processing Record 30 of Set 8 | hofn
# Processing Record 31 of Set 8 | palmer
# Processing Record 32 of Set 8 | cartagena
# Processing Record 33 of Set 8 | balvanesti
# Processing Record 34 of Set 8 | korla
# Processing Record 35 of Set 8 | panguipulli
# Processing Record 36 of Set 8 | lieksa
# Processing Record 37 of Set 8 | solnechnyy
# Processing Record 38 of Set 8 | bandar
# Processing Record 39 of Set 8 | montgomery
# Processing Record 40 of Set 8 | kauhajoki
# Processing Record 41 of Set 8 | port-cartier
# Processing Record 42 of Set 8 | srednekolymsk
# Processing Record 43 of Set 8 | stornoway
# Processing Record 44 of Set 8 | vanimo
# Processing Record 45 of Set 8 | chokurdakh
# Processing Record 46 of Set 8 | epe
# Processing Record 47 of Set 8 | benjamin constant
# Processing Record 48 of Set 8 | eenhana
# Processing Record 49 of Set 8 | koutselion
# Processing Record 50 of Set 8 | mindelo
# Processing Record 1 of Set 9 | hurricane
# Processing Record 2 of Set 9 | smithers
# Processing Record 3 of Set 9 | severo-kurilsk
# Processing Record 4 of Set 9 | martinsville
# Processing Record 5 of Set 9 | aldan
# Processing Record 6 of Set 9 | mocuba
# Processing Record 7 of Set 9 | san rafael
# Processing Record 8 of Set 9 | bukama
# Processing Record 9 of Set 9 | souillac
# Processing Record 10 of Set 9 | morros
# Processing Record 11 of Set 9 | asfi
# Processing Record 12 of Set 9 | kungur
# Processing Record 13 of Set 9 | kyabe
# Processing Record 14 of Set 9 | mrirt
# Processing Record 15 of Set 9 | rawson
# Processing Record 16 of Set 9 | tulu bolo
# Processing Record 17 of Set 9 | castano primo
# Processing Record 18 of Set 9 | beni
# Processing Record 19 of Set 9 | lorengau
# Processing Record 20 of Set 9 | atambua
# Processing Record 21 of Set 9 | port hardy
# Processing Record 22 of Set 9 | hasaki
# Processing Record 23 of Set 9 | bajil
# Processing Record 24 of Set 9 | maceio
# Processing Record 25 of Set 9 | ribeira grande
# Processing Record 26 of Set 9 | kudahuvadhoo
# Processing Record 27 of Set 9 | tsementnyy
# Processing Record 28 of Set 9 | tilichiki
# Processing Record 29 of Set 9 | zhigansk
# Processing Record 30 of Set 9 | kruisfontein
# Processing Record 31 of Set 9 | talaya
# Processing Record 32 of Set 9 | mount isa
# Processing Record 33 of Set 9 | egvekinot
# Processing Record 34 of Set 9 | zaysan
# Processing Record 35 of Set 9 | piet retief
# Processing Record 36 of Set 9 | colotlan
# Processing Record 37 of Set 9 | enshi
# Processing Record 38 of Set 9 | barstow
# Processing Record 39 of Set 9 | mount gambier
# Processing Record 40 of Set 9 | ceska skalice
# Processing Record 41 of Set 9 | tazovskiy
# Processing Record 42 of Set 9 | saint-pierre
# Processing Record 43 of Set 9 | luderitz
# Processing Record 44 of Set 9 | batangafo
# Processing Record 45 of Set 9 | igarka
# Processing Record 46 of Set 9 | sinjai
# Processing Record 47 of Set 9 | umba
# Processing Record 48 of Set 9 | zemio
# Processing Record 49 of Set 9 | fergus falls
# Processing Record 50 of Set 9 | rayachoti
# Processing Record 1 of Set 10 | goderich
# Processing Record 2 of Set 10 | ilabaya
# Processing Record 3 of Set 10 | troitskoye
# Processing Record 4 of Set 10 | nome
# Processing Record 5 of Set 10 | cockburn town
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | manggar
# Processing Record 8 of Set 10 | micheweni
# Processing Record 9 of Set 10 | port moresby
# Processing Record 10 of Set 10 | amazar
# Processing Record 11 of Set 10 | oga
# Processing Record 12 of Set 10 | alyangula
# Processing Record 13 of Set 10 | kamaishi
# Processing Record 14 of Set 10 | kangavar
# Processing Record 15 of Set 10 | beyneu
# Processing Record 16 of Set 10 | tamandare
# Processing Record 17 of Set 10 | saint-augustin
# Processing Record 18 of Set 10 | vanavara
# Processing Record 19 of Set 10 | asind
# Processing Record 20 of Set 10 | klyuchi
# Processing Record 21 of Set 10 | santiago
# Processing Record 22 of Set 10 | lashio
# Processing Record 23 of Set 10 | karratha
# Processing Record 24 of Set 10 | saleaula
# Processing Record 25 of Set 10 | port hedland
# Processing Record 26 of Set 10 | okha
# Processing Record 27 of Set 10 | mayo
# Processing Record 28 of Set 10 | kachikau
# Processing Record 29 of Set 10 | mezen
# Processing Record 30 of Set 10 | portland
# Processing Record 31 of Set 10 | malanje
# Processing Record 32 of Set 10 | guanica
# Processing Record 33 of Set 10 | haibowan
# Processing Record 34 of Set 10 | teya
# Processing Record 35 of Set 10 | sorvag
# Processing Record 36 of Set 10 | harwich
# Processing Record 37 of Set 10 | juneau
# Processing Record 38 of Set 10 | urusha
# Processing Record 39 of Set 10 | doctor pedro p. pena
# Processing Record 40 of Set 10 | mwaya
# Processing Record 41 of Set 10 | naberera
# Processing Record 42 of Set 10 | mishan
# Processing Record 43 of Set 10 | paracuru
# Processing Record 44 of Set 10 | nong khai
# Processing Record 45 of Set 10 | cabo san lucas
# Processing Record 46 of Set 10 | yucca valley
# Processing Record 47 of Set 10 | karaul
# Processing Record 48 of Set 10 | ratne
# Processing Record 49 of Set 10 | hay river
# Processing Record 50 of Set 10 | buribay
# Processing Record 1 of Set 11 | fukue
# Processing Record 2 of Set 11 | ambon
# Processing Record 3 of Set 11 | diffa
# Processing Record 4 of Set 11 | asau
# Processing Record 5 of Set 11 | santa eulalia del rio
# Processing Record 6 of Set 11 | iracoubo
# Processing Record 7 of Set 11 | santa marta
# Processing Record 8 of Set 11 | ukiah
# Processing Record 9 of Set 11 | quatre cocos
# Processing Record 10 of Set 11 | longyearbyen
# Processing Record 11 of Set 11 | kilindoni
# Processing Record 12 of Set 11 | chiali
# Processing Record 13 of Set 11 | inderborskiy
# Processing Record 14 of Set 11 | mapastepec
# Processing Record 15 of Set 11 | esil
# Processing Record 16 of Set 11 | zalantun
# Processing Record 17 of Set 11 | tiarei
# Processing Record 18 of Set 11 | camasca
# Processing Record 19 of Set 11 | koksovyy
# Processing Record 20 of Set 11 | nagato
# Processing Record 21 of Set 11 | plettenberg bay
# Processing Record 22 of Set 11 | sretensk
# Processing Record 23 of Set 11 | acarau
# Processing Record 24 of Set 11 | ayan
# Processing Record 25 of Set 11 | kissidougou
# Processing Record 26 of Set 11 | pokhara
# Processing Record 27 of Set 11 | chagda
# Processing Record 28 of Set 11 | gao
# Processing Record 29 of Set 11 | puerto carreno
# Processing Record 30 of Set 11 | impfondo
# Processing Record 31 of Set 11 | dali
# Processing Record 32 of Set 11 | jiayuguan
# Processing Record 33 of Set 11 | morondava
# Processing Record 34 of Set 11 | kerteh
# Processing Record 35 of Set 11 | loanda
# Processing Record 36 of Set 11 | port lincoln
# Processing Record 37 of Set 11 | kamenskoye
# Processing Record 38 of Set 11 | adrar
# Processing Record 39 of Set 11 | bogotol
# Processing Record 40 of Set 11 | bojnurd
# Processing Record 41 of Set 11 | doba
# Processing Record 42 of Set 11 | la paz
# Processing Record 43 of Set 11 | moussoro
# Processing Record 44 of Set 11 | manbij
# Processing Record 45 of Set 11 | sayat
# Processing Record 46 of Set 11 | knysna
# Processing Record 47 of Set 11 | yulara
# Processing Record 48 of Set 11 | omagari
# Processing Record 49 of Set 11 | burnie
# Processing Record 50 of Set 11 | dalianwan
# Processing Record 1 of Set 12 | boende
# Processing Record 2 of Set 12 | jubayl
# Processing Record 3 of Set 12 | havre-saint-pierre
# Processing Record 4 of Set 12 | sinnar
# Processing Record 5 of Set 12 | ciudad real
# Processing Record 6 of Set 12 | hashtrud
# Processing Record 7 of Set 12 | tommot
# Processing Record 8 of Set 12 | aybak
# Processing Record 9 of Set 12 | malwan
# Processing Record 10 of Set 12 | mwinilunga
# Processing Record 11 of Set 12 | taburi
# Processing Record 12 of Set 12 | itoman
# Processing Record 13 of Set 12 | hobyo
# Processing Record 14 of Set 12 | balad
# Processing Record 15 of Set 12 | kolokani
# Processing Record 16 of Set 12 | port hueneme
# Processing Record 17 of Set 12 | kalevala
# Processing Record 18 of Set 12 | mandalgovi
# Processing Record 19 of Set 12 | mamallapuram
# Processing Record 20 of Set 12 | khammam
# Processing Record 21 of Set 12 | litovko
# Processing Record 22 of Set 12 | morro bay
# Processing Record 23 of Set 12 | dzhebariki-khaya
# Processing Record 24 of Set 12 | swellendam
# Processing Record 25 of Set 12 | luau
# Processing Record 26 of Set 12 | dalby
# Processing Record 27 of Set 12 | pala
# Processing Record 28 of Set 12 | muroto
# Processing Record 29 of Set 12 | moranbah
# Processing Record 30 of Set 12 | barranca
# Processing Record 31 of Set 12 | shimoda
# Processing Record 32 of Set 12 | vrangel
# Processing Record 33 of Set 12 | skibbereen
# Processing Record 34 of Set 12 | camana
# Processing Record 35 of Set 12 | dong xoai
# Processing Record 36 of Set 12 | springbok
# Processing Record 37 of Set 12 | ekibastuz
# Processing Record 38 of Set 12 | flekkefjord
# Processing Record 39 of Set 12 | port hawkesbury
# Processing Record 40 of Set 12 | palmerston
# Processing Record 41 of Set 12 | ossora
# Processing Record 42 of Set 12 | camocim
# Processing Record 43 of Set 12 | san antonio
# Processing Record 44 of Set 12 | nishihara
# Processing Record 45 of Set 12 | halalo
# Processing Record 46 of Set 12 | storsteinnes
# Processing Record 47 of Set 12 | port blair
# Processing Record 48 of Set 12 | edgewater
# Processing Record 49 of Set 12 | bonthe
# Processing Record 50 of Set 12 | revelstoke
# Processing Record 1 of Set 13 | wattegama
# Processing Record 2 of Set 13 | gat
# Processing Record 3 of Set 13 | bako
# Processing Record 4 of Set 13 | kindu
# Processing Record 5 of Set 13 | bourail
# Processing Record 6 of Set 13 | kamenka
# Processing Record 7 of Set 13 | flin flon
# Processing Record 8 of Set 13 | laje
# Processing Record 9 of Set 13 | zhangjiakou
# Processing Record 10 of Set 13 | boysun
# Processing Record 11 of Set 13 | linchuan
# Processing Record 12 of Set 13 | bikin
# Processing Record 13 of Set 13 | rapid valley
# Processing Record 14 of Set 13 | kaputa
# Processing Record 15 of Set 13 | westport
# Processing Record 16 of Set 13 | gimbi
# Processing Record 17 of Set 13 | sao jose da coroa grande
# Processing Record 18 of Set 13 | hovd
# Processing Record 19 of Set 13 | lavrentiya
# Processing Record 20 of Set 13 | namatanai
# ---------------------------------------------
#  .xX-> RETRIEVAL OF DATA2 HAS COMPLETED <-Xx.
# ---------------------------------------------

# %%
# Print city_data to confirm sufficient count
len(city_data2)
# Out:
# 620

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data2_df = pd.DataFrame(city_data2)

# %%
# Create an empty list to hold the weather data
city_data3 = []

# Print the beginning of the logging
print(" .xX-> RETRIEVAL OF DATA3 HAS COMMENCED <-Xx. ")
print("---------------------------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
#  .xX-> RETRIEVAL OF DATA3 HAS COMMENCED <-Xx.
# ---------------------------------------------

# %%
# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
       
        # Parse out the needed data - 3h.
        city_snow = city_weather["snow"]["3h"]
    
        # Append the rain information into city_data2 list
        city_data3.append({"City": city.title(),
                           "Snow (Inches)": city_snow
                           })
    except:    
        try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
       
            # Parse out the needed data - 1h.
            city_snow = city_weather["snow"]["1h"]
            
             # Append the rain information into city_data2 list
            city_data3.append({"City": city.title(),
                               "Snow (Inches)": city_snow
                               })
    
        except:
             # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
       
            # Append the rain information into city_data2 list
            city_data3.append({"City": city.title(),
                              "Snow (Inches)": 0
                              })
    
    pass
    
# Indicate that Data Loading is complete
print("---------------------------------------------")
print(" .xX-> RETRIEVAL OF DATA3 HAS COMPLETED <-Xx. ")
print("---------------------------------------------")
# Out:
# Processing Record 1 of Set 1 | praia
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | buariki
# Processing Record 9 of Set 1 | geraldton
# Processing Record 10 of Set 1 | kamphaeng phet
# Processing Record 11 of Set 1 | severnyy-kospashskiy
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | gilgil
# Processing Record 14 of Set 1 | sivaki
# Processing Record 15 of Set 1 | dalinghe
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | mahina
# Processing Record 18 of Set 1 | marsh harbour
# Processing Record 19 of Set 1 | meulaboh
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | puerto escondido
# Processing Record 22 of Set 1 | sobolevo
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | tres passos
# Processing Record 27 of Set 1 | tezu
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | peniche
# Processing Record 32 of Set 1 | kurchum
# Processing Record 33 of Set 1 | potiskum
# Processing Record 34 of Set 1 | bellmead
# Processing Record 35 of Set 1 | bam
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | suntar
# Processing Record 38 of Set 1 | cururupu
# Processing Record 39 of Set 1 | kaseda
# Processing Record 40 of Set 1 | sfantu gheorghe
# Processing Record 41 of Set 1 | deputatskiy
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | muli
# Processing Record 46 of Set 1 | grimshaw
# Processing Record 47 of Set 1 | nioro
# Processing Record 48 of Set 1 | hualmay
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | mandan
# Processing Record 1 of Set 2 | simao
# Processing Record 2 of Set 2 | barentsburg
# Processing Record 3 of Set 2 | sovetskiy
# Processing Record 4 of Set 2 | toropets
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | woerden
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | dunedin
# Processing Record 9 of Set 2 | vao
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | vila franca do campo
# Processing Record 13 of Set 2 | simbahan
# Processing Record 14 of Set 2 | banjar
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | huarmey
# Processing Record 18 of Set 2 | taolanaro
# Processing Record 19 of Set 2 | moctezuma
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | umm lajj
# Processing Record 22 of Set 2 | port-gentil
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | ugoofaaru
# Processing Record 25 of Set 2 | kuytun
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | prince rupert
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | celestun
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | grindavik
# Processing Record 32 of Set 2 | maine-soroa
# Processing Record 33 of Set 2 | pakokku
# Processing Record 34 of Set 2 | sao miguel do araguaia
# Processing Record 35 of Set 2 | odessa
# Processing Record 36 of Set 2 | cayenne
# Processing Record 37 of Set 2 | katsuura
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | hami
# Processing Record 40 of Set 2 | tidore
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | starkville
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | herat
# Processing Record 48 of Set 2 | kalabo
# Processing Record 49 of Set 2 | luganville
# Processing Record 50 of Set 2 | nantucket
# Processing Record 1 of Set 3 | santa cruz
# Processing Record 2 of Set 3 | sambava
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | tawkar
# Processing Record 5 of Set 3 | ketchikan
# Processing Record 6 of Set 3 | oranjemund
# Processing Record 7 of Set 3 | sorong
# Processing Record 8 of Set 3 | kandila
# Processing Record 9 of Set 3 | ashtian
# Processing Record 10 of Set 3 | beringovskiy
# Processing Record 11 of Set 3 | puerto narino
# Processing Record 12 of Set 3 | wenling
# Processing Record 13 of Set 3 | moron
# Processing Record 14 of Set 3 | bontang
# Processing Record 15 of Set 3 | te anau
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | castro
# Processing Record 19 of Set 3 | daryapur
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | tabou
# Processing Record 22 of Set 3 | alice springs
# Processing Record 23 of Set 3 | sabha
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | alto araguaia
# Processing Record 26 of Set 3 | buy
# Processing Record 27 of Set 3 | mackay
# Processing Record 28 of Set 3 | grand gaube
# Processing Record 29 of Set 3 | palabuhanratu
# Processing Record 30 of Set 3 | sanmenxia
# Processing Record 31 of Set 3 | kiruna
# Processing Record 32 of Set 3 | half moon bay
# Processing Record 33 of Set 3 | san pedro
# Processing Record 34 of Set 3 | harper
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | wheeling
# Processing Record 37 of Set 3 | bara
# Processing Record 38 of Set 3 | grand river south east
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | vilyuysk
# Processing Record 42 of Set 3 | sankt valentin
# Processing Record 43 of Set 3 | galgani
# Processing Record 44 of Set 3 | north platte
# Processing Record 45 of Set 3 | bedele
# Processing Record 46 of Set 3 | port alfred
# Processing Record 47 of Set 3 | pedro ii
# Processing Record 48 of Set 3 | sao joao da barra
# Processing Record 49 of Set 3 | san cristobal
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | elat
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | amberley
# Processing Record 4 of Set 4 | axim
# Processing Record 5 of Set 4 | kiama
# Processing Record 6 of Set 4 | nanortalik
# Processing Record 7 of Set 4 | tuatapere
# Processing Record 8 of Set 4 | lincoln
# Processing Record 9 of Set 4 | ixtapa
# Processing Record 10 of Set 4 | champerico
# Processing Record 11 of Set 4 | bandrele
# Processing Record 12 of Set 4 | vestmannaeyjar
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | rutland
# Processing Record 15 of Set 4 | lavras
# Processing Record 16 of Set 4 | kupang
# Processing Record 17 of Set 4 | tasiilaq
# Processing Record 18 of Set 4 | shache
# Processing Record 19 of Set 4 | namie
# Processing Record 20 of Set 4 | harbour breton
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | porto santo
# Processing Record 23 of Set 4 | beniganj
# Processing Record 24 of Set 4 | samusu
# Processing Record 25 of Set 4 | sol-iletsk
# Processing Record 26 of Set 4 | dharchula
# Processing Record 27 of Set 4 | trinidad
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | mys shmidta
# Processing Record 30 of Set 4 | sabang
# Processing Record 31 of Set 4 | nawada
# Processing Record 32 of Set 4 | lompoc
# Processing Record 33 of Set 4 | buraydah
# Processing Record 34 of Set 4 | bargal
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | walvis bay
# Processing Record 37 of Set 4 | gazanjyk
# Processing Record 38 of Set 4 | sapernoye
# Processing Record 39 of Set 4 | nyurba
# Processing Record 40 of Set 4 | chitral
# Processing Record 41 of Set 4 | taltal
# Processing Record 42 of Set 4 | rungata
# Processing Record 43 of Set 4 | mar del plata
# Processing Record 44 of Set 4 | attawapiskat
# Processing Record 45 of Set 4 | japura
# Processing Record 46 of Set 4 | atasu
# Processing Record 47 of Set 4 | batsfjord
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | norman wells
# Processing Record 50 of Set 4 | dafeng
# Processing Record 1 of Set 5 | caravelas
# Processing Record 2 of Set 5 | avarua
# Processing Record 3 of Set 5 | santiago del estero
# Processing Record 4 of Set 5 | bathsheba
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | beloha
# Processing Record 7 of Set 5 | koumac
# Processing Record 8 of Set 5 | bacolod
# Processing Record 9 of Set 5 | lucapa
# Processing Record 10 of Set 5 | kathmandu
# Processing Record 11 of Set 5 | kirensk
# Processing Record 12 of Set 5 | namtsy
# Processing Record 13 of Set 5 | balezino
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | roma
# Processing Record 16 of Set 5 | sijunjung
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | charters towers
# Processing Record 19 of Set 5 | puerto ayacucho
# Processing Record 20 of Set 5 | ilulissat
# Processing Record 21 of Set 5 | isangel
# Processing Record 22 of Set 5 | yuzhno-yeniseyskiy
# Processing Record 23 of Set 5 | necochea
# Processing Record 24 of Set 5 | belushya guba
# Processing Record 25 of Set 5 | sinnamary
# Processing Record 26 of Set 5 | kota kinabalu
# Processing Record 27 of Set 5 | lagoa
# Processing Record 28 of Set 5 | bambous virieux
# Processing Record 29 of Set 5 | kisanga
# Processing Record 30 of Set 5 | ilo
# Processing Record 31 of Set 5 | labuhan
# Processing Record 32 of Set 5 | parrita
# Processing Record 33 of Set 5 | kismayo
# Processing Record 34 of Set 5 | mayumba
# Processing Record 35 of Set 5 | amahai
# Processing Record 36 of Set 5 | henties bay
# Processing Record 37 of Set 5 | matara
# Processing Record 38 of Set 5 | brae
# Processing Record 39 of Set 5 | laguna
# Processing Record 40 of Set 5 | nhulunbuy
# Processing Record 41 of Set 5 | pacific grove
# Processing Record 42 of Set 5 | pastavy
# Processing Record 43 of Set 5 | pandavapura
# Processing Record 44 of Set 5 | klaksvik
# Processing Record 45 of Set 5 | clyde river
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | ormara
# Processing Record 48 of Set 5 | kargasok
# Processing Record 49 of Set 5 | lebu
# Processing Record 50 of Set 5 | toftir
# Processing Record 1 of Set 6 | hunza
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | cap malheureux
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | khorramshahr
# Processing Record 6 of Set 6 | poum
# Processing Record 7 of Set 6 | georgetown
# Processing Record 8 of Set 6 | verkhovazhye
# Processing Record 9 of Set 6 | hihifo
# Processing Record 10 of Set 6 | comodoro rivadavia
# Processing Record 11 of Set 6 | college
# Processing Record 12 of Set 6 | rocha
# Processing Record 13 of Set 6 | almeirim
# Processing Record 14 of Set 6 | bolungarvik
# Processing Record 15 of Set 6 | constitucion
# Processing Record 16 of Set 6 | east london
# Processing Record 17 of Set 6 | warqla
# Processing Record 18 of Set 6 | chiang klang
# Processing Record 19 of Set 6 | genoa
# Processing Record 20 of Set 6 | rovaniemi
# Processing Record 21 of Set 6 | bengkulu
# Processing Record 22 of Set 6 | san policarpo
# Processing Record 23 of Set 6 | camalu
# Processing Record 24 of Set 6 | cabedelo
# Processing Record 25 of Set 6 | kavieng
# Processing Record 26 of Set 6 | vila do maio
# Processing Record 27 of Set 6 | cumaribo
# Processing Record 28 of Set 6 | mozarlandia
# Processing Record 29 of Set 6 | aquiraz
# Processing Record 30 of Set 6 | ilhabela
# Processing Record 31 of Set 6 | hambantota
# Processing Record 32 of Set 6 | dingle
# Processing Record 33 of Set 6 | chicama
# Processing Record 34 of Set 6 | taywarah
# Processing Record 35 of Set 6 | nikolskoye
# Processing Record 36 of Set 6 | nefteyugansk
# Processing Record 37 of Set 6 | demirci
# Processing Record 38 of Set 6 | dombarovskiy
# Processing Record 39 of Set 6 | snezhnogorsk
# Processing Record 40 of Set 6 | ust-nera
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | trunovskoye
# Processing Record 43 of Set 6 | takoradi
# Processing Record 44 of Set 6 | miri
# Processing Record 45 of Set 6 | bay roberts
# Processing Record 46 of Set 6 | launceston
# Processing Record 47 of Set 6 | naftah
# Processing Record 48 of Set 6 | gavle
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | vaitupu
# Processing Record 1 of Set 7 | guiyang
# Processing Record 2 of Set 7 | amderma
# Processing Record 3 of Set 7 | muros
# Processing Record 4 of Set 7 | aykhal
# Processing Record 5 of Set 7 | itarema
# Processing Record 6 of Set 7 | batemans bay
# Processing Record 7 of Set 7 | zhanatas
# Processing Record 8 of Set 7 | tumannyy
# Processing Record 9 of Set 7 | kangaatsiaq
# Processing Record 10 of Set 7 | north bend
# Processing Record 11 of Set 7 | arlit
# Processing Record 12 of Set 7 | raymond
# Processing Record 13 of Set 7 | sisimiut
# Processing Record 14 of Set 7 | nemuro
# Processing Record 15 of Set 7 | madison
# Processing Record 16 of Set 7 | krasnyy chikoy
# Processing Record 17 of Set 7 | oriximina
# Processing Record 18 of Set 7 | teacapan
# Processing Record 19 of Set 7 | camargo
# Processing Record 20 of Set 7 | linshu
# Processing Record 21 of Set 7 | atar
# Processing Record 22 of Set 7 | sentyabrskiy
# Processing Record 23 of Set 7 | seoul
# Processing Record 24 of Set 7 | doha
# Processing Record 25 of Set 7 | muborak
# Processing Record 26 of Set 7 | progreso
# Processing Record 27 of Set 7 | lasa
# Processing Record 28 of Set 7 | codrington
# Processing Record 29 of Set 7 | margate
# Processing Record 30 of Set 7 | plouzane
# Processing Record 31 of Set 7 | la palma
# Processing Record 32 of Set 7 | coahuayana
# Processing Record 33 of Set 7 | san juan
# Processing Record 34 of Set 7 | shelburne
# Processing Record 35 of Set 7 | kenai
# Processing Record 36 of Set 7 | varca
# Processing Record 37 of Set 7 | tessalit
# Processing Record 38 of Set 7 | nizhneyansk
# Processing Record 39 of Set 7 | yumen
# Processing Record 40 of Set 7 | lazaro cardenas
# Processing Record 41 of Set 7 | krasnoarmeysk
# Processing Record 42 of Set 7 | ararat
# Processing Record 43 of Set 7 | noshiro
# Processing Record 44 of Set 7 | nampa
# Processing Record 45 of Set 7 | utiroa
# Processing Record 46 of Set 7 | gursarai
# Processing Record 47 of Set 7 | volsk
# Processing Record 48 of Set 7 | veraval
# Processing Record 49 of Set 7 | coquimbo
# Processing Record 50 of Set 7 | mareeba
# Processing Record 1 of Set 8 | narsaq
# Processing Record 2 of Set 8 | berlevag
# Processing Record 3 of Set 8 | ahipara
# Processing Record 4 of Set 8 | nicoya
# Processing Record 5 of Set 8 | abong mbang
# Processing Record 6 of Set 8 | olden
# Processing Record 7 of Set 8 | illoqqortoormiut
# Processing Record 8 of Set 8 | padre paraiso
# Processing Record 9 of Set 8 | marawi
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | qaqortoq
# Processing Record 12 of Set 8 | tomatlan
# Processing Record 13 of Set 8 | kinkala
# Processing Record 14 of Set 8 | nouakchott
# Processing Record 15 of Set 8 | zhuhai
# Processing Record 16 of Set 8 | kattivakkam
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | gamboula
# Processing Record 19 of Set 8 | umm jarr
# Processing Record 20 of Set 8 | matagami
# Processing Record 21 of Set 8 | guerrero negro
# Processing Record 22 of Set 8 | pineville
# Processing Record 23 of Set 8 | verkhnevilyuysk
# Processing Record 24 of Set 8 | ilesha
# Processing Record 25 of Set 8 | balkhash
# Processing Record 26 of Set 8 | sandpoint
# Processing Record 27 of Set 8 | huambo
# Processing Record 28 of Set 8 | tsihombe
# Processing Record 29 of Set 8 | mehamn
# Processing Record 30 of Set 8 | hofn
# Processing Record 31 of Set 8 | palmer
# Processing Record 32 of Set 8 | cartagena
# Processing Record 33 of Set 8 | balvanesti
# Processing Record 34 of Set 8 | korla
# Processing Record 35 of Set 8 | panguipulli
# Processing Record 36 of Set 8 | lieksa
# Processing Record 37 of Set 8 | solnechnyy
# Processing Record 38 of Set 8 | bandar
# Processing Record 39 of Set 8 | montgomery
# Processing Record 40 of Set 8 | kauhajoki
# Processing Record 41 of Set 8 | port-cartier
# Processing Record 42 of Set 8 | srednekolymsk
# Processing Record 43 of Set 8 | stornoway
# Processing Record 44 of Set 8 | vanimo
# Processing Record 45 of Set 8 | chokurdakh
# Processing Record 46 of Set 8 | epe
# Processing Record 47 of Set 8 | benjamin constant
# Processing Record 48 of Set 8 | eenhana
# Processing Record 49 of Set 8 | koutselion
# Processing Record 50 of Set 8 | mindelo
# Processing Record 1 of Set 9 | hurricane
# Processing Record 2 of Set 9 | smithers
# Processing Record 3 of Set 9 | severo-kurilsk
# Processing Record 4 of Set 9 | martinsville
# Processing Record 5 of Set 9 | aldan
# Processing Record 6 of Set 9 | mocuba
# Processing Record 7 of Set 9 | san rafael
# Processing Record 8 of Set 9 | bukama
# Processing Record 9 of Set 9 | souillac
# Processing Record 10 of Set 9 | morros
# Processing Record 11 of Set 9 | asfi
# Processing Record 12 of Set 9 | kungur
# Processing Record 13 of Set 9 | kyabe
# Processing Record 14 of Set 9 | mrirt
# Processing Record 15 of Set 9 | rawson
# Processing Record 16 of Set 9 | tulu bolo
# Processing Record 17 of Set 9 | castano primo
# Processing Record 18 of Set 9 | beni
# Processing Record 19 of Set 9 | lorengau
# Processing Record 20 of Set 9 | atambua
# Processing Record 21 of Set 9 | port hardy
# Processing Record 22 of Set 9 | hasaki
# Processing Record 23 of Set 9 | bajil
# Processing Record 24 of Set 9 | maceio
# Processing Record 25 of Set 9 | ribeira grande
# Processing Record 26 of Set 9 | kudahuvadhoo
# Processing Record 27 of Set 9 | tsementnyy
# Processing Record 28 of Set 9 | tilichiki
# Processing Record 29 of Set 9 | zhigansk
# Processing Record 30 of Set 9 | kruisfontein
# Processing Record 31 of Set 9 | talaya
# Processing Record 32 of Set 9 | mount isa
# Processing Record 33 of Set 9 | egvekinot
# Processing Record 34 of Set 9 | zaysan
# Processing Record 35 of Set 9 | piet retief
# Processing Record 36 of Set 9 | colotlan
# Processing Record 37 of Set 9 | enshi
# Processing Record 38 of Set 9 | barstow
# Processing Record 39 of Set 9 | mount gambier
# Processing Record 40 of Set 9 | ceska skalice
# Processing Record 41 of Set 9 | tazovskiy
# Processing Record 42 of Set 9 | saint-pierre
# Processing Record 43 of Set 9 | luderitz
# Processing Record 44 of Set 9 | batangafo
# Processing Record 45 of Set 9 | igarka
# Processing Record 46 of Set 9 | sinjai
# Processing Record 47 of Set 9 | umba
# Processing Record 48 of Set 9 | zemio
# Processing Record 49 of Set 9 | fergus falls
# Processing Record 50 of Set 9 | rayachoti
# Processing Record 1 of Set 10 | goderich
# Processing Record 2 of Set 10 | ilabaya
# Processing Record 3 of Set 10 | troitskoye
# Processing Record 4 of Set 10 | nome
# Processing Record 5 of Set 10 | cockburn town
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | manggar
# Processing Record 8 of Set 10 | micheweni
# Processing Record 9 of Set 10 | port moresby
# Processing Record 10 of Set 10 | amazar
# Processing Record 11 of Set 10 | oga
# Processing Record 12 of Set 10 | alyangula
# Processing Record 13 of Set 10 | kamaishi
# Processing Record 14 of Set 10 | kangavar
# Processing Record 15 of Set 10 | beyneu
# Processing Record 16 of Set 10 | tamandare
# Processing Record 17 of Set 10 | saint-augustin
# Processing Record 18 of Set 10 | vanavara
# Processing Record 19 of Set 10 | asind
# Processing Record 20 of Set 10 | klyuchi
# Processing Record 21 of Set 10 | santiago
# Processing Record 22 of Set 10 | lashio
# Processing Record 23 of Set 10 | karratha
# Processing Record 24 of Set 10 | saleaula
# Processing Record 25 of Set 10 | port hedland
# Processing Record 26 of Set 10 | okha
# Processing Record 27 of Set 10 | mayo
# Processing Record 28 of Set 10 | kachikau
# Processing Record 29 of Set 10 | mezen
# Processing Record 30 of Set 10 | portland
# Processing Record 31 of Set 10 | malanje
# Processing Record 32 of Set 10 | guanica
# Processing Record 33 of Set 10 | haibowan
# Processing Record 34 of Set 10 | teya
# Processing Record 35 of Set 10 | sorvag
# Processing Record 36 of Set 10 | harwich
# Processing Record 37 of Set 10 | juneau
# Processing Record 38 of Set 10 | urusha
# Processing Record 39 of Set 10 | doctor pedro p. pena
# Processing Record 40 of Set 10 | mwaya
# Processing Record 41 of Set 10 | naberera
# Processing Record 42 of Set 10 | mishan
# Processing Record 43 of Set 10 | paracuru
# Processing Record 44 of Set 10 | nong khai
# Processing Record 45 of Set 10 | cabo san lucas
# Processing Record 46 of Set 10 | yucca valley
# Processing Record 47 of Set 10 | karaul
# Processing Record 48 of Set 10 | ratne
# Processing Record 49 of Set 10 | hay river
# Processing Record 50 of Set 10 | buribay
# Processing Record 1 of Set 11 | fukue
# Processing Record 2 of Set 11 | ambon
# Processing Record 3 of Set 11 | diffa
# Processing Record 4 of Set 11 | asau
# Processing Record 5 of Set 11 | santa eulalia del rio
# Processing Record 6 of Set 11 | iracoubo
# Processing Record 7 of Set 11 | santa marta
# Processing Record 8 of Set 11 | ukiah
# Processing Record 9 of Set 11 | quatre cocos
# Processing Record 10 of Set 11 | longyearbyen
# Processing Record 11 of Set 11 | kilindoni
# Processing Record 12 of Set 11 | chiali
# Processing Record 13 of Set 11 | inderborskiy
# Processing Record 14 of Set 11 | mapastepec
# Processing Record 15 of Set 11 | esil
# Processing Record 16 of Set 11 | zalantun
# Processing Record 17 of Set 11 | tiarei
# Processing Record 18 of Set 11 | camasca
# Processing Record 19 of Set 11 | koksovyy
# Processing Record 20 of Set 11 | nagato
# Processing Record 21 of Set 11 | plettenberg bay
# Processing Record 22 of Set 11 | sretensk
# Processing Record 23 of Set 11 | acarau
# Processing Record 24 of Set 11 | ayan
# Processing Record 25 of Set 11 | kissidougou
# Processing Record 26 of Set 11 | pokhara
# Processing Record 27 of Set 11 | chagda
# Processing Record 28 of Set 11 | gao
# Processing Record 29 of Set 11 | puerto carreno
# Processing Record 30 of Set 11 | impfondo
# Processing Record 31 of Set 11 | dali
# Processing Record 32 of Set 11 | jiayuguan
# Processing Record 33 of Set 11 | morondava
# Processing Record 34 of Set 11 | kerteh
# Processing Record 35 of Set 11 | loanda
# Processing Record 36 of Set 11 | port lincoln
# Processing Record 37 of Set 11 | kamenskoye
# Processing Record 38 of Set 11 | adrar
# Processing Record 39 of Set 11 | bogotol
# Processing Record 40 of Set 11 | bojnurd
# Processing Record 41 of Set 11 | doba
# Processing Record 42 of Set 11 | la paz
# Processing Record 43 of Set 11 | moussoro
# Processing Record 44 of Set 11 | manbij
# Processing Record 45 of Set 11 | sayat
# Processing Record 46 of Set 11 | knysna
# Processing Record 47 of Set 11 | yulara
# Processing Record 48 of Set 11 | omagari
# Processing Record 49 of Set 11 | burnie
# Processing Record 50 of Set 11 | dalianwan
# Processing Record 1 of Set 12 | boende
# Processing Record 2 of Set 12 | jubayl
# Processing Record 3 of Set 12 | havre-saint-pierre
# Processing Record 4 of Set 12 | sinnar
# Processing Record 5 of Set 12 | ciudad real
# Processing Record 6 of Set 12 | hashtrud
# Processing Record 7 of Set 12 | tommot
# Processing Record 8 of Set 12 | aybak
# Processing Record 9 of Set 12 | malwan
# Processing Record 10 of Set 12 | mwinilunga
# Processing Record 11 of Set 12 | taburi
# Processing Record 12 of Set 12 | itoman
# Processing Record 13 of Set 12 | hobyo
# Processing Record 14 of Set 12 | balad
# Processing Record 15 of Set 12 | kolokani
# Processing Record 16 of Set 12 | port hueneme
# Processing Record 17 of Set 12 | kalevala
# Processing Record 18 of Set 12 | mandalgovi
# Processing Record 19 of Set 12 | mamallapuram
# Processing Record 20 of Set 12 | khammam
# Processing Record 21 of Set 12 | litovko
# Processing Record 22 of Set 12 | morro bay
# Processing Record 23 of Set 12 | dzhebariki-khaya
# Processing Record 24 of Set 12 | swellendam
# Processing Record 25 of Set 12 | luau
# Processing Record 26 of Set 12 | dalby
# Processing Record 27 of Set 12 | pala
# Processing Record 28 of Set 12 | muroto
# Processing Record 29 of Set 12 | moranbah
# Processing Record 30 of Set 12 | barranca
# Processing Record 31 of Set 12 | shimoda
# Processing Record 32 of Set 12 | vrangel
# Processing Record 33 of Set 12 | skibbereen
# Processing Record 34 of Set 12 | camana
# Processing Record 35 of Set 12 | dong xoai
# Processing Record 36 of Set 12 | springbok
# Processing Record 37 of Set 12 | ekibastuz
# Processing Record 38 of Set 12 | flekkefjord
# Processing Record 39 of Set 12 | port hawkesbury
# Processing Record 40 of Set 12 | palmerston
# Processing Record 41 of Set 12 | ossora
# Processing Record 42 of Set 12 | camocim
# Processing Record 43 of Set 12 | san antonio
# Processing Record 44 of Set 12 | nishihara
# Processing Record 45 of Set 12 | halalo
# Processing Record 46 of Set 12 | storsteinnes
# Processing Record 47 of Set 12 | port blair
# Processing Record 48 of Set 12 | edgewater
# Processing Record 49 of Set 12 | bonthe
# Processing Record 50 of Set 12 | revelstoke
# Processing Record 1 of Set 13 | wattegama
# Processing Record 2 of Set 13 | gat
# Processing Record 3 of Set 13 | bako
# Processing Record 4 of Set 13 | kindu
# Processing Record 5 of Set 13 | bourail
# Processing Record 6 of Set 13 | kamenka
# Processing Record 7 of Set 13 | flin flon
# Processing Record 8 of Set 13 | laje
# Processing Record 9 of Set 13 | zhangjiakou
# Processing Record 10 of Set 13 | boysun
# Processing Record 11 of Set 13 | linchuan
# Processing Record 12 of Set 13 | bikin
# Processing Record 13 of Set 13 | rapid valley
# Processing Record 14 of Set 13 | kaputa
# Processing Record 15 of Set 13 | westport
# Processing Record 16 of Set 13 | gimbi
# Processing Record 17 of Set 13 | sao jose da coroa grande
# Processing Record 18 of Set 13 | hovd
# Processing Record 19 of Set 13 | lavrentiya
# Processing Record 20 of Set 13 | namatanai
# ---------------------------------------------
#  .xX-> RETRIEVAL OF DATA3 HAS COMPLETED <-Xx.
# ---------------------------------------------

# %%
# Print city_data to confirm sufficient count
len(city_data3)
# Out:
# 620

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data3_df = pd.DataFrame(city_data3)

# %%
# Merge city_data1_df with city_data2_df
city_dataX_df = pd.merge(city_data1_df,city_data2_df, on="City", how="left") 

# Merge city_dataX_df with city_data3_df
city_data_df = pd.merge(city_dataX_df,city_data3_df, on="City", how="left") 
city_data_df
# Out:
#                          City Country    Lat     Lng  Max Temp  Humidity  \
# 0                       Praia      CV  14.92  -23.51     87.80        40
# 1                   Cape Town      ZA -33.93   18.42     60.01       100
# 2                   Busselton      AU -33.65  115.33     62.01        73
# 3                     Rikitea      PF -23.12 -134.97     76.53        85
# 4                      Atuona      PF  -9.80 -139.03     80.47        71
# ..                        ...     ...    ...     ...       ...       ...
# 561                     Gimbi      ET   9.17   35.83     61.72        97
# 562  Sao Jose Da Coroa Grande      BR  -8.90  -35.15     83.59        70
# 563                      Hovd      MN  48.01   91.64     47.64        49
# 564                Lavrentiya      RU  65.58 -171.00     32.40        96
# 565                 Namatanai      PG  -3.67  152.43     79.09        82
#
#      Cloudiness  Wind Speed Current Description  Rain (Inches)  Snow (Inches)
# 0             0       17.22           clear sky           0.00            0.0
# 1            75       13.87          light rain           0.51            0.0
# 2            25       18.66    scattered clouds           0.00            0.0
# 3            75       10.04          light rain           0.42            0.0
# 4             6       11.12           clear sky           0.00            0.0
# ..          ...         ...                 ...            ...            ...
# 561          89        2.30       moderate rain           2.20            0.0
# 562          11        6.46          light rain           0.13            0.0
# 563          78        5.41       broken clouds           0.00            0.0
# 564         100        6.62     overcast clouds           0.00            0.0
# 565          10        4.12          light rain           0.25            0.0
#
# [566 rows x 11 columns]

# %%
# Create the output .csv file
output_data_file = "weather_database/WeatherPy_challenge.csv"

# Export WeatherPy_challenge into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# How many cities have recorded rainfall?
city_data_df[city_data_df["Rain (Inches)"] != 0].count()
# Out:
# City                   74
# Country                74
# Lat                    74
# Lng                    74
# Max Temp               74
# Humidity               74
# Cloudiness             74
# Wind Speed             74
# Current Description    74
# Rain (Inches)          74
# Snow (Inches)          74
# dtype: int64

# %%
# How many cities have recorded snow?
city_data_df[city_data_df["Snow (Inches)"] != 0].count()
# Out:
# City                   3
# Country                3
# Lat                    3
# Lng                    3
# Max Temp               3
# Humidity               3
# Cloudiness             3
# Wind Speed             3
# Current Description    3
# Rain (Inches)          3
# Snow (Inches)          3
# dtype: int64
